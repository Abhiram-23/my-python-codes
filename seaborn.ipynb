# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
sns.set(style = 'darkgrid')

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
sns.relplot(x='total_bill',y='tip',data = tips)

# %%
sns.relplot(x='total_bill',y='tip',data = tips,hue='smoker')

# %%
sns.relplot(x='total_bill',y="tip",data = tips , hue = "smoker",style="time")

# %%
sns.relplot(x='total_bill',y='tip',hue='size',data=tips,palette='ch:r=0.5,l=0.5')

# %%
sns.relplot(x='total_bill',y='tip',hue='tip',size='sex',data=tips,height=5)

# %%
sns.relplot(x='total_bill',y='tip',data=tips,size='size',sizes=(20,100))

# %%
from numpy.random import randn

# %%
df=pd.DataFrame(dict(time=np.arange(500),value=randn(500).cumsum()))

# %%
df.head()
# Out:
#    time     value
# 0     0  0.993384
# 1     1  0.566822
# 2     2  2.013256
# 3     3  1.226110
# 4     4  1.385458

# %%
sns.relplot(x='time',y='value',kind='line',data=df)

# %%
fmri=sns.load_dataset('fmri')
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.relplot(x='timepoint',y='signal',kind='line',data=fmri,ci='sd')

# %%
sns.relplot(x='timepoint',y='signal',size='event',style='event',hue='event',data=fmri,kind='line')

# %%
sns.relplot(x='timepoint',y='signal',kind='line',data=fmri.query("event=='stim'"),units='subject',style='event',hue='region',estimator=None)

# %%
dots=sns.load_dataset('dots').query("align=='dots'")

# %%
dots.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
sns.relplot(x='time',y='firing_rate',data=dots,kind='line',hue='coherence',style='choice')

# %%
palette=sns.cubehelix_palette(n_colors=6,start=0,
    rot=0.4,
    gamma=2,
    hue=0.8,
    light=1,
    reverse=False,
    as_cmap=False,)

# %%
sns.relplot(x='time',y='firing_rate',palette=palette,style='choice',kind='line',hue='coherence',data=dots)

# %%
df=pd.DataFrame(dict(time=pd.date_range('19-5-2020',periods=500),value=randn(500).cumsum()))
df.head()
# Out:
#         time     value
# 0 2020-05-19 -0.168900
# 1 2020-05-20 -0.738174
# 2 2020-05-21  0.729469
# 3 2020-05-22  0.478157
# 4 2020-05-23  1.920875

# %%
g=sns.relplot(x='time',y='value',data=df,kind='line')
g.fig.autofmt_xdate()

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x='total_bill',y='tip',hue='smoker',col='size',data=tips,col_wrap=3,height=3,estimator=None)

# %%
fmri.query("timepoint<=10")
# Out:
#      subject  timepoint event    region    signal
# 17        s7          9  stim  parietal  0.058897
# 36        s8          9  stim  parietal  0.170227
# 67        s0          0  stim   frontal -0.021452
# 84        s1          0  stim  parietal -0.064454
# 113      s13         10  stim  parietal -0.074503
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [616 rows x 5 columns]

# %%
sns.lineplot(x='timepoint',y='signal',style='event',hue='region',data=fmri,markers=True,ci=70,err_style='bars')

# %%
sns.lineplot(x='timepoint',y='signal',hue='event',units='subject',data=fmri.query("region=='frontal'"),estimator=None)

# %%
dots.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
sns.lineplot(x='time',y='firing_rate',data=dots,hue='choice',style='coherence')

# %%
iris=sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.scatterplot(x='sepal_length',y='petal_length',data=iris,size='petal_width',style='species')

# %%
titanic=sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.scatterplot(x='day',y='total_bill',data=tips,hue='day')

# %%
sns.catplot(x='day',y='total_bill',data=tips)

# %%
sns.catplot(x='day',y='total_bill',data=tips,jitter=False)

# %%
sns.catplot(x='day',y='total_bill',data=tips,kind='swarm',hue='size')

# %%
sns.catplot(x='day',y='total_bill',kind='box',data=tips,dodge=False,hue='sex')

# %%
diamond=sns.load_dataset('diamonds')

# %%
diamond.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.catplot(x='color',y='price',data=diamond.sort_values('color'),kind='boxen')

# %%
sns.catplot(y='day',x='total_bill',data=tips,kind='violin',hue='sex',split=True)

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.catplot(x='sex',y='survived',data=titanic,hue='class',kind='bar')

# %%
x=randn(100)

# %%
x
# Out:
# array([ 3.62688903e-02,  2.66892095e-02,  3.04068187e-01, -1.25792555e+00,
#         8.44141949e-02,  7.31968712e-01,  4.45784555e-01, -1.61781767e+00,
#         3.83644273e-02, -8.46483106e-01, -9.62969509e-01,  1.03025561e+00,
#         9.22904482e-01,  1.76667986e+00, -4.19588581e-01, -8.51343827e-01,
#        -7.82523150e-01, -1.60630265e-01, -8.28208348e-01, -2.60823418e-01,
#        -3.06726734e-01,  1.66960350e-01, -7.19311721e-02,  1.30179279e+00,
#        -2.77851090e-01, -9.28478802e-01, -3.19047275e-02,  1.01324303e+00,
#        -1.85530824e+00,  8.76485564e-01, -9.54610835e-03, -1.89511360e-01,
#         9.02286877e-01, -2.67360031e-01, -2.01353541e+00, -6.63633950e-01,
#        -1.32973926e+00, -2.79019633e-01, -1.87343803e+00, -1.13270741e+00,
#         9.16256044e-02, -6.55769903e-01, -8.03106856e-01,  6.66502623e-01,
#        -2.41680798e-01, -1.52536213e+00,  2.60195124e+00, -6.11383605e-01,
# ...

# %%
sns.distplot(x,kde=False,bins=10,color='red')

# %%
sns.kdeplot(x,shade=True,cut=10)

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='kde')

# %%
sns.pairplot(iris)

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
g=sns.PairGrid(iris)
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.kdeplot)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.regplot(x='size',y='tip',data=tips,x_estimator=np.mean)

# %%
data=sns.load_dataset('anscombe')

# %%
data.head()
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %%
sns.lmplot(x='x',y='y',data=data.query("dataset=='I'"),ci=None,scatter_kws={'s':80})

# %%
sns.lmplot(x='x',y='y',data=data.query("dataset=='II'"),ci=None,scatter_kws={'s':80},order=2)

# %%
sns.lmplot(x='x',y='y',data=data.query("dataset=='II'"),ci=None,scatter_kws={'s':80},robust=True)

# %%
sns.lmplot(x='x',y='y',data=data.query("dataset=='III'"),ci=None,scatter_kws={'s':80},robust=True)
